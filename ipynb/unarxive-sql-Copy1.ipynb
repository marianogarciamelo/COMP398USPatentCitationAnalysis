# %% [markdown]
# # UnarXive analysis

# %%
import os
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine, inspect
from adbc_driver_postgresql import dbapi

# --- Configuration ---
BASE_DIR = Path('./')
ENV_PATH = BASE_DIR / "creds.env"
load_dotenv(dotenv_path=ENV_PATH)

DB_USER = os.getenv("DB_USER", "postgres")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST", "localhost")
DB_NAME = os.getenv("DB_NAME", "unarxive")

CONNECTION_STRING = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}"
engine = create_engine(CONNECTION_STRING)

# %%
def run_query(query: str, engine=engine) -> pd.DataFrame:
  return pd.read_sql(query, engine)

# %%
# 1. Get list of all tables in the database
inspector = inspect(engine)
tables = inspector.get_table_names()
print(f'{tables=}')
# Out:
# tables=[]

# %%
papers_df = (
  pd.read_sql_table(
    table_name='papers', con=engine,
    parse_dates='update_date',
  )
)
papers_df
# Out:
#                 paper_id                                              title  \
# 0             1901.00039             Mask-aware networks for crowd counting
# 1             1901.00068      A Bayesian Spatial Model for Imaging Genetics
# 2             1901.00286  Wavefunction of Plasmon Excitations with Space...
# 3             1901.00312  Symmetry-guided nonrigid registration: the cas...
# 4             1901.00198            S-dual Amplitude and D3-Brane Couplings
# ...                  ...                                                ...
# 164995   physics/9706034  A solution of the measurement problem in quant...
# 164996   physics/9706033  A solution of the spacetime singularity proble...
# 164997  cond-mat/9706142  Statistical Properties of Unrestricted Crew Sc...
# 164998  cond-mat/9709005  Non-equilibrium Superconductivity and Quasipar...
# 164999  cond-mat/9812072  Electronic Structure, Correlation Effects and ...
#
#                                             abstract_text  \
# 0         Crowd counting problem aims to count the num...
# 1         We develop a Bayesian bivariate spatial mode...
# 2         The one dimensional (1D) driven quantum coup...
# 3         Image symmetrization is an effective strateg...
# 4         Recently, it has been observed that the IIB ...
# ...                                                   ...
# 164995    The problem of a correct description of the ...
# 164996    The spacetime singularity in relativistic co...
# 164997    A statistical analysis is performed for a ra...
# 164998    We present a study of non-equilibrium superc...
# 164999    The book includes all main physical properti...
#
#                     submitter                             doi  \
# 0              Shengqin Jiang                            None
# 1                    Yin Song                            None
# 2       M Akbari Moghanjoughi               10.1063/1.5087201
# 3            Rui Patrick Xian  10.1016/j.ultramic.2019.04.004
# 4         Komeil Babaei Velni      10.1103/PhysRevD.99.066007
# ...                       ...                             ...
# 164995        Jae-Hyung Myung                            None
# 164996        Jae-Hyung Myung                            None
# 164997       Carsten Peterson                            None
# 164998     Dirk van der Marel     10.1103/PhysRevLett.79.4890
# 164999        Valentin Irkhin                            None
#
#                                                  comments  \
# 0                                                    None
# 1                                                    None
# 2                                      18 pages 5 figures
# 3                                                    None
# 4                                                18 pages
# ...                                                   ...
# 164995                       11 pages, Latex 1 jpg figure
# 164996                     10 pages, Latex, 3 JPG figures
# 164997                       15 pages LaTeX, 2 ps figures
# 164998                                 4 pages, 3 figures
# 164999  TeX files of the text of the book, style is en...
#
#                                                   license update_date  \
# 0             http://creativecommons.org/licenses/by/4.0/  2019-06-21
# 1             http://creativecommons.org/licenses/by/4.0/  2020-05-26
# 2             http://creativecommons.org/licenses/by/4.0/  2019-03-27
# 3          http://creativecommons.org/licenses/by-sa/4.0/  2020-05-19
# 4       http://creativecommons.org/publicdomain/zero/1.0/  2019-03-27
# ...                                                   ...         ...
# 164995        http://creativecommons.org/licenses/by/3.0/  2012-03-30
# 164996        http://creativecommons.org/licenses/by/3.0/  2012-04-06
# 164997        http://creativecommons.org/licenses/by/4.0/  2020-12-23
# 164998        http://creativecommons.org/licenses/by/4.0/  2022-05-11
# 164999        http://creativecommons.org/licenses/by/4.0/  2021-09-01
#
#         discipline
# 0       Statistics
# 1       Statistics
# 2          Physics
# 3          Physics
# 4          Physics
# ...            ...
# 164995     Physics
# 164996     Physics
# 164997     Physics
# 164998     Physics
# 164999     Physics
#
# [165000 rows x 9 columns]

# %%
CONNECTION_STRING
# Out:
# 'postgresql+psycopg2://mgarciamelo:cotsEk-5padby-jivgib@147.126.2.24/postgres'
